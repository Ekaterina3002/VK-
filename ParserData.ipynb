# %%
"""
Utility for collecting VK user data and building pairwise friendship features.
The script expects an environment variable VK_TOKEN with a user token that has
at least the scopes `friends`, `groups`, and `offline`. Adjust the SEED_IDS
list below to control the starting users (e.g. members of a study group).
Outputs (written to data/):
    users.csv      - attributes of each open user that was collected
    friends.csv    - undirected friendships between collected users
    groups.csv     - group memberships for collected users
    features.csv   - pairwise features for TARGET_IDS combinations
"""
from __future__ import annotations
import json
import math
import os
import time
from collections import deque
from datetime import date
from pathlib import Path
from typing import Dict, Iterable, List, Optional, Set, Tuple
import pandas as pd
from dotenv import load_dotenv
import vk_api
from vk_api.exceptions import ApiError

load_dotenv()
token = os.getenv("VK_TOKEN")
if not token:
    raise ValueError("❌ Токен не найден! Добавьте VK_TOKEN в файл .env")

vk_session = vk_api.VkApi(token=token)
vk = vk_session.get_api()

# === Configuration ===========================================================
SEED_IDS: List[int] = [251116606]  # стартовые пользователи (указать вручную)
TARGET_IDS: Optional[List[int]] = None  # по умолчанию берём SEED_IDS позже
MAX_DEPTH: int = 2  # 0: только seed, 1: добавляем их друзей и т.д.
USER_LIMIT: Optional[int] = None  # ограничение на число открытых профилей
API_DELAY = 0.34  # безопасный интервал между запросами (сек.)
MAX_RETRIES = 5
USER_FIELDS = ",".join(
    [
        "sex",
        "bdate",
        "city",
        "country",
        "universities",
        "schools",
        "occupation",
        "career",
        "followers_count",
        "counters",
    ]
)
CACHE_DIR = Path("data/cache")
USERS_CACHE = CACHE_DIR / "users"
FRIENDS_CACHE = CACHE_DIR / "friends"
GROUPS_CACHE = CACHE_DIR / "groups"
OUTPUT_DIR = Path("data")
# === Helpers =================================================================
def ensure_dir(path: Path) -> None:
    path.mkdir(parents=True, exist_ok=True)
def clean_text(value: Optional[str]) -> Optional[str]:
    if not value:
        return None
    return value.strip() or None
def normalize(value: Optional[str]) -> Optional[str]:
    text = clean_text(value)
    return text.lower() if text else None
def choose_name(candidate: dict, keys: Iterable[str]) -> Optional[str]:
    for key in keys:
        value = candidate.get(key)
        if value:
            return clean_text(str(value))
    return None
def load_cache(path: Path) -> Optional[dict]:
    if path.exists():
        with path.open("r", encoding="utf-8") as fh:
            return json.load(fh)
    return None
def save_cache(path: Path, payload: dict) -> None:
    ensure_dir(path.parent)
    with path.open("w", encoding="utf-8") as fh:
        json.dump(
            payload, fh,
            ensure_ascii=False, indent=2,
            default=lambda o: sorted(o) if isinstance(o, set) else o
        )
def safe_api_call(method, *, description: str, **kwargs):
    """Call VK API with retries and throttling."""
    delay = API_DELAY
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = method(**kwargs)
            time.sleep(API_DELAY)
            return response
        except ApiError as error:
            # 6 — too many requests per second; 10/29 — rate limit; retry with backoff.
            if error.code in {6, 10, 29}:
                time.sleep(delay)
                delay *= 2
                continue
            raise RuntimeError(f"{description} failed: {error.code} {error}") from error
    raise RuntimeError(f"{description} failed after {MAX_RETRIES} retries")
def parse_age(bdate: Optional[str]) -> Optional[int]:
    """Return age in years if full birth date is available and plausible."""
    if not bdate or bdate.count(".") != 2:
        return None
    day_str, month_str, year_str = bdate.split(".")
    if not year_str.isdigit():
        return None
    try:
        day, month, year = int(day_str), int(month_str), int(year_str)
        born = date(year, month, day)
    except ValueError:
        return None
    today = date.today()
    age = today.year - born.year - (
        (today.month, today.day) < (born.month, born.day)
    )
    if age < 12 or age > 90:
        return None
    return age
def normalize_list(items: Iterable[str]) -> List[str]:
    return sorted({clean_text(item) for item in items if clean_text(item)})
def normalization_set(items: Iterable[str]) -> Set[str]:
    return {normalize(item) for item in items if normalize(item)}
# === VK data extraction ======================================================
def fetch_user_profile(vk, user_id: int) -> Optional[dict]:
    cache_path = USERS_CACHE / f"{user_id}.json"
    cached = load_cache(cache_path)
    if cached:
        return cached
    try:
        raw_users = safe_api_call(
            vk.users.get,
            description=f"users.get for {user_id}",
            user_ids=user_id,
            fields=USER_FIELDS,
        )
    except RuntimeError as error:
        print(error)
        return None
    if not raw_users:
        return None
    raw = raw_users[0]
    if raw.get("is_closed"):
        return None
    city = raw.get("city", {}) or {}
    country = raw.get("country", {}) or {}
    universities_raw = raw.get("universities") or []
    schools_raw = raw.get("schools") or []
    career_raw = raw.get("career") or []
    universities = [
        choose_name(uni, ["name", "title", "university_name"])
        for uni in universities_raw
    ]
    faculties = [
        choose_name(uni, ["faculty_name", "chair_name"])
        for uni in universities_raw
    ]
    schools = [
        choose_name(sch, ["name", "title"])
        for sch in schools_raw
    ]
    works = [
        choose_name(job, ["company", "position", "name"])
        for job in career_raw
    ]
    counters = raw.get("counters") or {}
    friends_count = counters.get("friends")
    followers_count = raw.get("followers_count", counters.get("followers"))
    profile = {
        "id": raw["id"],
        "first_name": clean_text(raw.get("first_name")),
        "last_name": clean_text(raw.get("last_name")),
        "city": clean_text(city.get("title")),
        "city_norm": normalize(city.get("title")),
        "country": clean_text(country.get("title")),
        "country_norm": normalize(country.get("title")),
        "sex": raw.get("sex"),
        "age": parse_age(raw.get("bdate")),
        "universities": normalize_list(universities),
        "universities_norm": normalization_set(universities),
        "faculties": normalize_list(faculties),
        "faculties_norm": normalization_set(faculties),
        "schools": normalize_list(schools),
        "schools_norm": normalization_set(schools),
        "works": normalize_list(works),
        "works_norm": normalization_set(works),
        "friends_count": friends_count,
        "followers_count": followers_count,
    }
    save_cache(cache_path, profile)
    return profile
def fetch_friends(vk, user_id: int) -> Set[int]:
    cache_path = FRIENDS_CACHE / f"{user_id}.json"
    cached = load_cache(cache_path)
    if cached is not None:
        return set(cached)
    try:
        response = safe_api_call(
            vk.friends.get,
            description=f"friends.get for {user_id}",
            user_id=user_id,
        )
    except RuntimeError as error:
        print(error)
        save_cache(cache_path, [])
        return set()
    friends = set(response.get("items", []))
    save_cache(cache_path, sorted(friends))
    return friends
def fetch_groups(vk, user_id: int) -> Set[int]:
    cache_path = GROUPS_CACHE / f"{user_id}.json"
    cached = load_cache(cache_path)
    if cached is not None:
        return set(cached)
    groups: Set[int] = set()
    offset = 0
    count = 1000
    while True:
        try:
            response = safe_api_call(
                vk.groups.get,
                description=f"groups.get for {user_id}",
                user_id=user_id,
                count=count,
                offset=offset,
            )
        except RuntimeError as error:
            print(error)
            break
        batch = response.get("items", [])
        groups.update(batch)
        if len(batch) < count:
            break
        offset += count
    save_cache(cache_path, sorted(groups))
    return groups
def collect_graph(
    vk,
    seed_ids: Iterable[int],
    *,
    depth: int,
    user_limit: Optional[int],
) -> Tuple[Dict[int, dict], Dict[int, Set[int]], Dict[int, Set[int]]]:
    queue = deque([(uid, 0) for uid in set(seed_ids)])
    visited: Set[int] = set()
    profiles: Dict[int, dict] = {}
    friends_map: Dict[int, Set[int]] = {}
    groups_map: Dict[int, Set[int]] = {}
    while queue:
        user_id, current_depth = queue.popleft()
        if user_id in visited:
            continue
        visited.add(user_id)
        profile = fetch_user_profile(vk, user_id)
        if not profile:
            continue
        profiles[user_id] = profile
        friends = fetch_friends(vk, user_id)
        friends_map[user_id] = friends
        if depth is None or current_depth < depth:
            for friend_id in friends:
                if friend_id not in visited:
                    queue.append((friend_id, current_depth + 1))
        groups = fetch_groups(vk, user_id)
        groups_map[user_id] = groups
        if user_limit and len(profiles) >= user_limit:
            break
    return profiles, friends_map, groups_map
# === Feature engineering =====================================================
def adamic_adar_score(
    common_friends: Set[int],
    friends_map: Dict[int, Set[int]],
    profiles: Dict[int, dict],
) -> float:
    score = 0.0
    for friend_id in common_friends:
        degree = len(friends_map.get(friend_id, []))
        if degree <= 1:
            degree = profiles.get(friend_id, {}).get("friends_count")
        if degree and degree > 1:
            score += 1.0 / math.log(degree)
    return score
def compute_features(
    user_ids: Iterable[int],
    profiles: Dict[int, dict],
    friends_map: Dict[int, Set[int]],
    groups_map: Dict[int, Set[int]],
) -> List[dict]:
    rows: List[dict] = []
    user_list = [uid for uid in user_ids if uid in profiles]
    user_list.sort()
    for idx, uid_a in enumerate(user_list):
        for uid_b in user_list[idx + 1 :]:
            profile_a = profiles[uid_a]
            profile_b = profiles[uid_b]
            friends_a = friends_map.get(uid_a, set())
            friends_b = friends_map.get(uid_b, set())
            common_friends = friends_a & friends_b
            union_friends = friends_a | friends_b
            jaccard_friends = (
                len(common_friends) / len(union_friends) if union_friends else 0.0
            )
            groups_a = groups_map.get(uid_a, set())
            groups_b = groups_map.get(uid_b, set())
            common_groups = groups_a & groups_b
            union_groups = groups_a | groups_b
            jaccard_groups = (
                len(common_groups) / len(union_groups) if union_groups else 0.0
            )
            same_city = int(
                profile_a.get("city_norm")
                and profile_a.get("city_norm") == profile_b.get("city_norm")
            )
            same_university = int(
                bool(profile_a.get("universities_norm") & profile_b.get("universities_norm"))
            )
            same_faculty = int(
                bool(profile_a.get("faculties_norm") & profile_b.get("faculties_norm"))
            )
            same_school = int(
                bool(profile_a.get("schools_norm") & profile_b.get("schools_norm"))
            )
            age_a = profile_a.get("age")
            age_b = profile_b.get("age")
            age_diff = abs(age_a - age_b) if age_a is not None and age_b is not None else None
            row = {
                "user_A": uid_a,
                "user_B": uid_b,
                "common_friends": len(common_friends),
                "jaccard_friends": jaccard_friends,
                "adamic_adar": adamic_adar_score(common_friends, friends_map, profiles),
                "same_city": same_city,
                "same_university": same_university,
                "same_faculty": same_faculty,
                "same_school": same_school,
                "age_diff": age_diff,
                "common_groups": len(common_groups),
                "jaccard_groups": jaccard_groups,
            }
            rows.append(row)
    return rows
# === Export utilities ========================================================
def join_values(values: Iterable[str]) -> str:
    return ";".join(sorted({value for value in values if value}))
def export_users(profiles: Dict[int, dict], destination: Path) -> None:
    records = []
    for profile in profiles.values():
        records.append(
            {
                "id": profile["id"],
                "first_name": profile.get("first_name"),
                "last_name": profile.get("last_name"),
                "city": profile.get("city"),
                "country": profile.get("country"),
                "sex": profile.get("sex"),
                "age": profile.get("age"),
                "universities": join_values(profile.get("universities", [])),
                "faculties": join_values(profile.get("faculties", [])),
                "schools": join_values(profile.get("schools", [])),
                "works": join_values(profile.get("works", [])),
                "friends_count": profile.get("friends_count"),
                "followers_count": profile.get("followers_count"),
            }
        )
    df = pd.DataFrame(records)
    df.to_csv(destination, index=False)
def export_friends(
    profiles: Dict[int, dict],
    friends_map: Dict[int, Set[int]],
    destination: Path,
) -> None:
    known_ids = set(profiles.keys())
    edges = set()
    for uid, friends in friends_map.items():
        for fid in friends:
            if fid in known_ids and uid < fid:
                edges.add((uid, fid))
    df = pd.DataFrame(edges, columns=["user_A", "user_B"])
    df.to_csv(destination, index=False)
def export_groups(
    profiles: Dict[int, dict],
    groups_map: Dict[int, Set[int]],
    destination: Path,
) -> None:
    rows = []
    known_ids = set(profiles.keys())
    for uid, groups in groups_map.items():
        if uid not in known_ids:
            continue
        for gid in sorted(groups):
            rows.append({"user_id": uid, "group_id": gid})
    df = pd.DataFrame(rows)
    df.to_csv(destination, index=False)
def export_features(rows: List[dict], destination: Path) -> None:
    df = pd.DataFrame(rows)
    df.to_csv(destination, index=False)
# === Entry point =============================================================
def main():
    load_dotenv()
    token = os.getenv("VK_TOKEN")
    if not token:
        raise RuntimeError("VK_TOKEN is missing. Add it to your .env file.")
    ensure_dir(CACHE_DIR)
    ensure_dir(OUTPUT_DIR)
    vk_session = vk_api.VkApi(token=token)
    vk = vk_session.get_api()
    profiles, friends_map, groups_map = collect_graph(
        vk,
        seed_ids=SEED_IDS,
        depth=MAX_DEPTH,
        user_limit=USER_LIMIT,
    )
    if not profiles:
        raise RuntimeError("No open profiles were collected. Check permissions.")
    feature_ids = TARGET_IDS if TARGET_IDS is not None else SEED_IDS
    feature_rows = compute_features(feature_ids, profiles, friends_map, groups_map)
    export_users(profiles, OUTPUT_DIR / "users.csv")
    export_friends(profiles, friends_map, OUTPUT_DIR / "friends.csv")
    export_groups(profiles, groups_map, OUTPUT_DIR / "groups.csv")
    export_features(feature_rows, OUTPUT_DIR / "features.csv")
    print(f"Collected {len(profiles)} open users.")
    print(f"Wrote users, friends, groups, and features CSV to {OUTPUT_DIR.resolve()}")
if __name__ == "__main__":
    main()
# Out:
# friends.get for 221041702 failed: 18 [18] User was deleted or banned
# groups.get for 221041702 failed: 18 [18] User was deleted or banned
# friends.get for 318368868 failed: 18 [18] User was deleted or banned
# groups.get for 318368868 failed: 18 [18] User was deleted or banned
# friends.get for 277705371 failed: 18 [18] User was deleted or banned
# groups.get for 277705371 failed: 18 [18] User was deleted or banned
# friends.get for 384622761 failed: 18 [18] User was deleted or banned
# groups.get for 384622761 failed: 18 [18] User was deleted or banned
# friends.get for 309326115 failed: 18 [18] User was deleted or banned
# groups.get for 309326115 failed: 18 [18] User was deleted or banned
# friends.get for 258049928 failed: 18 [18] User was deleted or banned
# groups.get for 258049928 failed: 18 [18] User was deleted or banned
# friends.get for 376888763 failed: 18 [18] User was deleted or banned
# groups.get for 376888763 failed: 18 [18] User was deleted or banned
# friends.get for 227937236 failed: 18 [18] User was deleted or banned
# groups.get for 227937236 failed: 18 [18] User was deleted or banned
# friends.get for 269277183 failed: 18 [18] User was deleted or banned
# groups.get for 269277183 failed: 18 [18] User was deleted or banned
# friends.get for 380937986 failed: 18 [18] User was deleted or banned
# groups.get for 380937986 failed: 18 [18] User was deleted or banned
# friends.get for 254312222 failed: 18 [18] User was deleted or banned
# groups.get for 254312222 failed: 18 [18] User was deleted or banned
# friends.get for 683889522 failed: 18 [18] User was deleted or banned
# groups.get for 683889522 failed: 18 [18] User was deleted or banned
# friends.get for 334817281 failed: 18 [18] User was deleted or banned
# groups.get for 334817281 failed: 18 [18] User was deleted or banned
# friends.get for 234678312 failed: 18 [18] User was deleted or banned
# groups.get for 234678312 failed: 18 [18] User was deleted or banned
# friends.get for 321137784 failed: 18 [18] User was deleted or banned
# groups.get for 321137784 failed: 18 [18] User was deleted or banned
# friends.get for 203104931 failed: 18 [18] User was deleted or banned
# groups.get for 203104931 failed: 18 [18] User was deleted or banned
# friends.get for 453562178 failed: 18 [18] User was deleted or banned
# groups.get for 453562178 failed: 18 [18] User was deleted or banned
# friends.get for 545493830 failed: 18 [18] User was deleted or banned
# groups.get for 545493830 failed: 18 [18] User was deleted or banned
# friends.get for 209279308 failed: 18 [18] User was deleted or banned
# groups.get for 209279308 failed: 18 [18] User was deleted or banned
# friends.get for 474718555 failed: 18 [18] User was deleted or banned
# groups.get for 474718555 failed: 18 [18] User was deleted or banned
# friends.get for 231234398 failed: 18 [18] User was deleted or banned
# groups.get for 231234398 failed: 18 [18] User was deleted or banned
# friends.get for 185995703 failed: 18 [18] User was deleted or banned
# groups.get for 185995703 failed: 18 [18] User was deleted or banned
# friends.get for 378683832 failed: 18 [18] User was deleted or banned
# groups.get for 378683832 failed: 18 [18] User was deleted or banned
# friends.get for 322897360 failed: 18 [18] User was deleted or banned
# groups.get for 322897360 failed: 18 [18] User was deleted or banned
# friends.get for 159053828 failed: 15 [15] Access denied: you are in users blacklist
# groups.get for 159053828 failed: 15 [15] Access denied: you are in users blacklist
# friends.get for 259177643 failed: 18 [18] User was deleted or banned
# groups.get for 259177643 failed: 18 [18] User was deleted or banned
# friends.get for 308759883 failed: 18 [18] User was deleted or banned
# groups.get for 308759883 failed: 18 [18] User was deleted or banned
# friends.get for 98440807 failed: 18 [18] User was deleted or banned
# groups.get for 98440807 failed: 18 [18] User was deleted or banned
# friends.get for 234395316 failed: 18 [18] User was deleted or banned
# groups.get for 234395316 failed: 18 [18] User was deleted or banned
# friends.get for 187605993 failed: 18 [18] User was deleted or banned
# groups.get for 187605993 failed: 18 [18] User was deleted or banned
# friends.get for 279776254 failed: 18 [18] User was deleted or banned
# groups.get for 279776254 failed: 18 [18] User was deleted or banned
# friends.get for 611720265 failed: 9 [9] Flood control
# friends.get for 558498381 failed: 9 [9] Flood control
# friends.get for 128111189 failed: 9 [9] Flood control
# friends.get for 182627934 failed: 9 [9] Flood control
# friends.get for 310651487 failed: 9 [9] Flood control
# friends.get for 532735070 failed: 9 [9] Flood control
# friends.get for 180522083 failed: 9 [9] Flood control
# friends.get for 248879721 failed: 9 [9] Flood control
# friends.get for 392923241 failed: 9 [9] Flood control
# friends.get for 193305707 failed: 9 [9] Flood control
# friends.get for 348565100 failed: 9 [9] Flood control
# friends.get for 164754542 failed: 9 [9] Flood control
# friends.get for 552709743 failed: 9 [9] Flood control
# groups.get for 552709743 failed: 18 [18] User was deleted or banned
# friends.get for 669244030 failed: 9 [9] Flood control
# friends.get for 377451135 failed: 9 [9] Flood control
# friends.get for 58958978 failed: 9 [9] Flood control
# friends.get for 289151107 failed: 9 [9] Flood control
# friends.get for 266506896 failed: 9 [9] Flood control
# friends.get for 138234513 failed: 9 [9] Flood control
# friends.get for 326852247 failed: 9 [9] Flood control
# friends.get for 401761433 failed: 9 [9] Flood control
# friends.get for 62302365 failed: 9 [9] Flood control
# friends.get for 181452445 failed: 9 [9] Flood control
# friends.get for 301586081 failed: 9 [9] Flood control
# friends.get for 233809574 failed: 9 [9] Flood control
# friends.get for 150364327 failed: 9 [9] Flood control
# friends.get for 304516778 failed: 9 [9] Flood control
# friends.get for 162143920 failed: 9 [9] Flood control
# friends.get for 468586160 failed: 9 [9] Flood control
# friends.get for 449708725 failed: 9 [9] Flood control
# friends.get for 448656056 failed: 9 [9] Flood control
# friends.get for 461792441 failed: 9 [9] Flood control
# friends.get for 584895 failed: 9 [9] Flood control
# friends.get for 141791937 failed: 9 [9] Flood control
# friends.get for 145681089 failed: 9 [9] Flood control
# friends.get for 320355520 failed: 9 [9] Flood control
# friends.get for 408891587 failed: 9 [9] Flood control
# friends.get for 455310533 failed: 9 [9] Flood control
# friends.get for 573702353 failed: 9 [9] Flood control
# friends.get for 459040466 failed: 9 [9] Flood control
# friends.get for 112326358 failed: 9 [9] Flood control
# friends.get for 530438369 failed: 9 [9] Flood control
# friends.get for 94782690 failed: 9 [9] Flood control
# friends.get for 270445800 failed: 9 [9] Flood control
# friends.get for 401122024 failed: 9 [9] Flood control
# friends.get for 174919915 failed: 9 [9] Flood control
# friends.get for 138325230 failed: 9 [9] Flood control
# friends.get for 136244984 failed: 9 [9] Flood control
# friends.get for 65299194 failed: 9 [9] Flood control
# friends.get for 257483002 failed: 9 [9] Flood control
# friends.get for 14769918 failed: 9 [9] Flood control
# friends.get for 241811200 failed: 9 [9] Flood control
# friends.get for 357129 failed: 9 [9] Flood control
# friends.get for 4949258 failed: 9 [9] Flood control
# friends.get for 435730700 failed: 9 [9] Flood control
# friends.get for 424899342 failed: 9 [9] Flood control
# friends.get for 497573646 failed: 9 [9] Flood control
# friends.get for 415011600 failed: 9 [9] Flood control
# friends.get for 144461587 failed: 9 [9] Flood control
# friends.get for 357725975 failed: 9 [9] Flood control
# friends.get for 375213336 failed: 9 [9] Flood control
# friends.get for 516888344 failed: 9 [9] Flood control
# friends.get for 492264730 failed: 9 [9] Flood control
# friends.get for 172194587 failed: 9 [9] Flood control
# friends.get for 222076189 failed: 9 [9] Flood control
# friends.get for 483219229 failed: 9 [9] Flood control
# friends.get for 566543135 failed: 9 [9] Flood control
# friends.get for 259799841 failed: 9 [9] Flood control
# friends.get for 304515362 failed: 9 [9] Flood control
# friends.get for 262282537 failed: 9 [9] Flood control
# friends.get for 309216041 failed: 9 [9] Flood control
# friends.get for 210199340 failed: 9 [9] Flood control
# friends.get for 94542129 failed: 9 [9] Flood control
# friends.get for 498030901 failed: 9 [9] Flood control
# friends.get for 248739640 failed: 9 [9] Flood control
# friends.get for 336024893 failed: 9 [9] Flood control
# groups.get for 336024893 failed: 18 [18] User was deleted or banned
# friends.get for 265084224 failed: 9 [9] Flood control
# friends.get for 437509445 failed: 9 [9] Flood control
# friends.get for 105338208 failed: 9 [9] Flood control
# friends.get for 305833827 failed: 9 [9] Flood control
# friends.get for 310638948 failed: 9 [9] Flood control
# friends.get for 64440176 failed: 9 [9] Flood control
# friends.get for 455674743 failed: 9 [9] Flood control
# friends.get for 51414392 failed: 9 [9] Flood control
# friends.get for 394716029 failed: 9 [9] Flood control
# friends.get for 511636861 failed: 9 [9] Flood control
# friends.get for 302368127 failed: 9 [9] Flood control
# friends.get for 481397633 failed: 9 [9] Flood control
# friends.get for 150542723 failed: 9 [9] Flood control
# friends.get for 303542660 failed: 9 [9] Flood control
# friends.get for 137547653 failed: 9 [9] Flood control
# friends.get for 230101381 failed: 9 [9] Flood control
# friends.get for 72263047 failed: 9 [9] Flood control
# friends.get for 379330948 failed: 9 [9] Flood control
# friends.get for 428618627 failed: 9 [9] Flood control
# friends.get for 491686794 failed: 9 [9] Flood control
# friends.get for 607777676 failed: 9 [9] Flood control
# friends.get for 453208976 failed: 9 [9] Flood control
# friends.get for 206356372 failed: 9 [9] Flood control
# friends.get for 252419477 failed: 9 [9] Flood control
# groups.get for 252419477 failed: 18 [18] User was deleted or banned
# friends.get for 140023716 failed: 9 [9] Flood control
# friends.get for 151200167 failed: 9 [9] Flood control
# friends.get for 217387951 failed: 9 [9] Flood control
# friends.get for 345599922 failed: 9 [9] Flood control
# friends.get for 426399669 failed: 9 [9] Flood control
# friends.get for 153128374 failed: 9 [9] Flood control
# friends.get for 293531065 failed: 9 [9] Flood control
# friends.get for 167511995 failed: 9 [9] Flood control
# friends.get for 224970684 failed: 9 [9] Flood control
# friends.get for 240476090 failed: 9 [9] Flood control
# friends.get for 157100479 failed: 9 [9] Flood control
# friends.get for 211551679 failed: 9 [9] Flood control
# friends.get for 537700799 failed: 9 [9] Flood control
# friends.get for 221919170 failed: 9 [9] Flood control
# friends.get for 399700937 failed: 9 [9] Flood control
# friends.get for 563272138 failed: 9 [9] Flood control
# friends.get for 187539403 failed: 9 [9] Flood control
# friends.get for 166016977 failed: 9 [9] Flood control
# friends.get for 269241808 failed: 9 [9] Flood control
# friends.get for 452727252 failed: 9 [9] Flood control
# friends.get for 222406614 failed: 9 [9] Flood control
# friends.get for 213576154 failed: 9 [9] Flood control
# friends.get for 304348126 failed: 9 [9] Flood control
# friends.get for 86918629 failed: 9 [9] Flood control
# friends.get for 341470181 failed: 9 [9] Flood control
# friends.get for 97531371 failed: 9 [9] Flood control
# friends.get for 161871852 failed: 9 [9] Flood control
# friends.get for 244426226 failed: 9 [9] Flood control
# friends.get for 329325048 failed: 9 [9] Flood control
# friends.get for 213194234 failed: 9 [9] Flood control
# friends.get for 464157179 failed: 9 [9] Flood control
# friends.get for 322610187 failed: 9 [9] Flood control
# friends.get for 633041433 failed: 9 [9] Flood control
# friends.get for 89834522 failed: 9 [9] Flood control
# friends.get for 232139295 failed: 9 [9] Flood control
# friends.get for 303822881 failed: 9 [9] Flood control
# friends.get for 400947745 failed: 9 [9] Flood control
# friends.get for 349082148 failed: 9 [9] Flood control
# friends.get for 220834855 failed: 9 [9] Flood control
# friends.get for 374853161 failed: 9 [9] Flood control
# friends.get for 373824042 failed: 9 [9] Flood control
# friends.get for 414090290 failed: 9 [9] Flood control
# friends.get for 413824057 failed: 9 [9] Flood control
# friends.get for 450947642 failed: 9 [9] Flood control
# friends.get for 239067707 failed: 9 [9] Flood control
# friends.get for 446524998 failed: 9 [9] Flood control
# friends.get for 482060370 failed: 9 [9] Flood control
# friends.get for 390936157 failed: 9 [9] Flood control
# friends.get for 211227742 failed: 9 [9] Flood control
# friends.get for 507909214 failed: 9 [9] Flood control
# friends.get for 1205349 failed: 9 [9] Flood control
# friends.get for 355231333 failed: 9 [9] Flood control
# friends.get for 387269748 failed: 9 [9] Flood control
# friends.get for 398500470 failed: 9 [9] Flood control
# friends.get for 332775549 failed: 9 [9] Flood control
# friends.get for 239565957 failed: 9 [9] Flood control
# friends.get for 209172104 failed: 9 [9] Flood control
# friends.get for 19692683 failed: 9 [9] Flood control
# friends.get for 406737555 failed: 9 [9] Flood control
# friends.get for 601583764 failed: 9 [9] Flood control
# friends.get for 267292309 failed: 9 [9] Flood control
# friends.get for 358352534 failed: 9 [9] Flood control
# friends.get for 466961558 failed: 9 [9] Flood control
# friends.get for 217725592 failed: 9 [9] Flood control
# friends.get for 389777563 failed: 9 [9] Flood control
# friends.get for 57613475 failed: 9 [9] Flood control
# friends.get for 665305762 failed: 9 [9] Flood control
# friends.get for 489844391 failed: 9 [9] Flood control
# friends.get for 140412072 failed: 9 [9] Flood control
# friends.get for 171966122 failed: 9 [9] Flood control
# friends.get for 244154540 failed: 9 [9] Flood control
# friends.get for 266351790 failed: 9 [9] Flood control
# friends.get for 557789358 failed: 9 [9] Flood control
# friends.get for 530652338 failed: 9 [9] Flood control
# friends.get for 710195385 failed: 9 [9] Flood control
# friends.get for 98606778 failed: 9 [9] Flood control
# friends.get for 386959038 failed: 9 [9] Flood control
# friends.get for 436185279 failed: 9 [9] Flood control
# friends.get for 194064066 failed: 9 [9] Flood control
# friends.get for 216897218 failed: 9 [9] Flood control
# friends.get for 216450244 failed: 9 [9] Flood control
# friends.get for 167694533 failed: 9 [9] Flood control
# friends.get for 672033492 failed: 9 [9] Flood control
# friends.get for 484445406 failed: 9 [9] Flood control
# friends.get for 597029601 failed: 9 [9] Flood control
# friends.get for 278777065 failed: 9 [9] Flood control
# friends.get for 386672879 failed: 9 [9] Flood control
# friends.get for 210762480 failed: 9 [9] Flood control
# friends.get for 480855791 failed: 9 [9] Flood control
# friends.get for 210812146 failed: 9 [9] Flood control
# friends.get for 1524982 failed: 9 [9] Flood control
# friends.get for 376054525 failed: 9 [9] Flood control
# friends.get for 463124226 failed: 9 [9] Flood control
# friends.get for 524025605 failed: 9 [9] Flood control
# friends.get for 251586319 failed: 9 [9] Flood control
# friends.get for 359320337 failed: 9 [9] Flood control
# groups.get for 359320337 failed: 18 [18] User was deleted or banned
# friends.get for 231968043 failed: 9 [9] Flood control
# friends.get for 218237239 failed: 9 [9] Flood control
# friends.get for 443166202 failed: 9 [9] Flood control
# friends.get for 433229652 failed: 9 [9] Flood control
# friends.get for 231573850 failed: 9 [9] Flood control
# friends.get for 607931740 failed: 9 [9] Flood control
# friends.get for 461696862 failed: 9 [9] Flood control
# friends.get for 341398369 failed: 9 [9] Flood control
# friends.get for 422250851 failed: 9 [9] Flood control
# friends.get for 301876072 failed: 9 [9] Flood control
# friends.get for 433722219 failed: 9 [9] Flood control
# friends.get for 441939823 failed: 9 [9] Flood control
# friends.get for 269619575 failed: 9 [9] Flood control
# friends.get for 318486399 failed: 9 [9] Flood control
# friends.get for 78315392 failed: 9 [9] Flood control
# friends.get for 606634883 failed: 9 [9] Flood control
# friends.get for 211431816 failed: 9 [9] Flood control
# friends.get for 211983756 failed: 9 [9] Flood control
# friends.get for 383524747 failed: 9 [9] Flood control
# friends.get for 192474516 failed: 9 [9] Flood control
# friends.get for 34773402 failed: 9 [9] Flood control
# friends.get for 249690526 failed: 9 [9] Flood control
# friends.get for 600090531 failed: 9 [9] Flood control
# friends.get for 406271397 failed: 9 [9] Flood control
# groups.get for 406271397 failed: 18 [18] User was deleted or banned
# friends.get for 362749862 failed: 9 [9] Flood control
# friends.get for 402274728 failed: 9 [9] Flood control
# friends.get for 225089964 failed: 9 [9] Flood control
# friends.get for 204438446 failed: 9 [9] Flood control
# friends.get for 352382383 failed: 9 [9] Flood control
# friends.get for 484563892 failed: 9 [9] Flood control
# friends.get for 245902773 failed: 9 [9] Flood control
# groups.get for 245902773 failed: 18 [18] User was deleted or banned
# friends.get for 332751798 failed: 9 [9] Flood control
# friends.get for 210788296 failed: 9 [9] Flood control
# friends.get for 252799949 failed: 9 [9] Flood control
# friends.get for 559749583 failed: 9 [9] Flood control
# friends.get for 235752409 failed: 9 [9] Flood control
# friends.get for 440036313 failed: 9 [9] Flood control
# friends.get for 450987491 failed: 9 [9] Flood control
# friends.get for 59689962 failed: 9 [9] Flood control
# friends.get for 109266924 failed: 9 [9] Flood control
# friends.get for 821376495 failed: 9 [9] Flood control
# groups.get for 821376495 failed: 18 [18] User was deleted or banned
# friends.get for 270008314 failed: 9 [9] Flood control
# friends.get for 385701374 failed: 9 [9] Flood control
# friends.get for 173633538 failed: 9 [9] Flood control
# friends.get for 432306189 failed: 9 [9] Flood control
# friends.get for 403918862 failed: 9 [9] Flood control
# friends.get for 448813072 failed: 9 [9] Flood control
# friends.get for 508772369 failed: 9 [9] Flood control
# friends.get for 105682968 failed: 9 [9] Flood control
# groups.get for 105682968 failed: 18 [18] User was deleted or banned
# friends.get for 349478947 failed: 9 [9] Flood control
# friends.get for 472295471 failed: 9 [9] Flood control
# friends.get for 255014960 failed: 9 [9] Flood control
# friends.get for 422322227 failed: 9 [9] Flood control
# friends.get for 166887477 failed: 9 [9] Flood control
# friends.get for 223754298 failed: 9 [9] Flood control
# friends.get for 308179012 failed: 9 [9] Flood control
# friends.get for 331731012 failed: 9 [9] Flood control
# friends.get for 823066695 failed: 9 [9] Flood control
# friends.get for 278913104 failed: 9 [9] Flood control
# friends.get for 225402973 failed: 9 [9] Flood control
# friends.get for 243380330 failed: 9 [9] Flood control
# friends.get for 461815920 failed: 9 [9] Flood control
# friends.get for 392036474 failed: 9 [9] Flood control
# friends.get for 158445696 failed: 9 [9] Flood control
# friends.get for 439652482 failed: 9 [9] Flood control
# friends.get for 488362121 failed: 9 [9] Flood control
# friends.get for 175749262 failed: 9 [9] Flood control
# friends.get for 297758866 failed: 9 [9] Flood control
# friends.get for 328147097 failed: 9 [9] Flood control
# friends.get for 243407007 failed: 9 [9] Flood control
# friends.get for 276885664 failed: 9 [9] Flood control
# friends.get for 362948769 failed: 9 [9] Flood control
# friends.get for 327006370 failed: 9 [9] Flood control
# groups.get for 327006370 failed: 18 [18] User was deleted or banned
# friends.get for 240650417 failed: 9 [9] Flood control
# friends.get for 447778997 failed: 9 [9] Flood control
# friends.get for 758474933 failed: 9 [9] Flood control
# friends.get for 419737791 failed: 9 [9] Flood control
# friends.get for 426803396 failed: 9 [9] Flood control
# friends.get for 525752529 failed: 9 [9] Flood control
# friends.get for 458547410 failed: 9 [9] Flood control
# friends.get for 323580122 failed: 9 [9] Flood control
# friends.get for 423583962 failed: 9 [9] Flood control
# friends.get for 155121890 failed: 9 [9] Flood control
# friends.get for 282765539 failed: 9 [9] Flood control
# friends.get for 182704363 failed: 9 [9] Flood control
# friends.get for 5538031 failed: 9 [9] Flood control
# friends.get for 449552627 failed: 9 [9] Flood control
# friends.get for 323369210 failed: 9 [9] Flood control
# friends.get for 153557248 failed: 9 [9] Flood control
# friends.get for 296984836 failed: 9 [9] Flood control
# friends.get for 441518340 failed: 9 [9] Flood control
# friends.get for 286877958 failed: 9 [9] Flood control
# friends.get for 379834632 failed: 9 [9] Flood control
# friends.get for 299936013 failed: 9 [9] Flood control
# friends.get for 523227408 failed: 9 [9] Flood control
# friends.get for 27504915 failed: 9 [9] Flood control
# friends.get for 754815253 failed: 9 [9] Flood control
# friends.get for 689146147 failed: 9 [9] Flood control
# friends.get for 151148837 failed: 9 [9] Flood control
# friends.get for 409504037 failed: 9 [9] Flood control
# friends.get for 478239015 failed: 9 [9] Flood control
# friends.get for 1870120 failed: 9 [9] Flood control
# friends.get for 5730603 failed: 9 [9] Flood control
# friends.get for 289683762 failed: 9 [9] Flood control
# friends.get for 204200251 failed: 9 [9] Flood control
# friends.get for 222779709 failed: 9 [9] Flood control
# friends.get for 146553153 failed: 9 [9] Flood control
# friends.get for 631005506 failed: 9 [9] Flood control
# friends.get for 173789510 failed: 9 [9] Flood control
# friends.get for 174111046 failed: 9 [9] Flood control
# friends.get for 467327304 failed: 9 [9] Flood control
# friends.get for 321071433 failed: 9 [9] Flood control
# friends.get for 10457422 failed: 9 [9] Flood control
# friends.get for 306624848 failed: 9 [9] Flood control
# friends.get for 220565847 failed: 9 [9] Flood control
# friends.get for 399442263 failed: 9 [9] Flood control
# friends.get for 166242651 failed: 9 [9] Flood control
# friends.get for 572586331 failed: 9 [9] Flood control
# friends.get for 275267938 failed: 9 [9] Flood control
# friends.get for 507965798 failed: 9 [9] Flood control
# groups.get for 507965798 failed: 18 [18] User was deleted or banned
# friends.get for 282059122 failed: 9 [9] Flood control
# friends.get for 333703544 failed: 9 [9] Flood control
# friends.get for 258832769 failed: 9 [9] Flood control
# friends.get for 268685699 failed: 9 [9] Flood control
# friends.get for 826720649 failed: 9 [9] Flood control
# friends.get for 287377802 failed: 9 [9] Flood control
# friends.get for 293878154 failed: 9 [9] Flood control
# friends.get for 293695892 failed: 9 [9] Flood control
# friends.get for 296485275 failed: 9 [9] Flood control
# friends.get for 77523367 failed: 9 [9] Flood control
# friends.get for 282526121 failed: 9 [9] Flood control
# friends.get for 388016555 failed: 9 [9] Flood control
# friends.get for 454773163 failed: 9 [9] Flood control
# friends.get for 69110189 failed: 9 [9] Flood control
# friends.get for 220481971 failed: 9 [9] Flood control
# friends.get for 496226739 failed: 9 [9] Flood control
# friends.get for 196248003 failed: 9 [9] Flood control
# friends.get for 612551108 failed: 9 [9] Flood control
# friends.get for 389052882 failed: 9 [9] Flood control
# friends.get for 478063060 failed: 9 [9] Flood control
# friends.get for 514830804 failed: 9 [9] Flood control
# friends.get for 67426774 failed: 9 [9] Flood control
# friends.get for 157315542 failed: 9 [9] Flood control
# friends.get for 303446486 failed: 9 [9] Flood control
# friends.get for 361892310 failed: 9 [9] Flood control
# friends.get for 477077977 failed: 9 [9] Flood control
# friends.get for 662741463 failed: 9 [9] Flood control
# friends.get for 34906592 failed: 9 [9] Flood control
# friends.get for 257333730 failed: 9 [9] Flood control
# friends.get for 448000482 failed: 9 [9] Flood control
# friends.get for 311945702 failed: 9 [9] Flood control
# friends.get for 167637481 failed: 9 [9] Flood control
# friends.get for 205449705 failed: 9 [9] Flood control
# friends.get for 203813361 failed: 9 [9] Flood control
# friends.get for 112120311 failed: 9 [9] Flood control
# friends.get for 269883904 failed: 9 [9] Flood control
# friends.get for 343857667 failed: 9 [9] Flood control
# friends.get for 341309958 failed: 9 [9] Flood control
# friends.get for 541731342 failed: 9 [9] Flood control
# friends.get for 429986323 failed: 9 [9] Flood control
# friends.get for 378233369 failed: 9 [9] Flood control
# friends.get for 456845849 failed: 9 [9] Flood control
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 428
#     426     print(f"Wrote users, friends, groups, and features CSV to {OUTPUT_DIR.resolve()}")
#     427 if __name__ == "__main__":
# --> 428     main()
#
# Cell In[6], line 411, in main()
#     409 vk_session = vk_api.VkApi(token=token)
#     410 vk = vk_session.get_api()
# --> 411 profiles, friends_map, groups_map = collect_graph(
#     412     vk,
#     413     seed_ids=SEED_IDS,
#     414     depth=MAX_DEPTH,
#     415     user_limit=USER_LIMIT,
#     416 )
#     417 if not profiles:
#     418     raise RuntimeError("No open profiles were collected. Check permissions.")
#
# Cell In[6], line 268, in collect_graph(vk, seed_ids, depth, user_limit)
#     266         if friend_id not in visited:
#     267             queue.append((friend_id, current_depth + 1))
# --> 268 groups = fetch_groups(vk, user_id)
#     269 groups_map[user_id] = groups
#     270 if user_limit and len(profiles) >= user_limit:
#
# Cell In[6], line 224, in fetch_groups(vk, user_id)
#     222 while True:
#     223     try:
# --> 224         response = safe_api_call(
#     225             vk.groups.get,
#     226             description=f"groups.get for {user_id}",
#     227             user_id=user_id,
#     228             count=count,
#     229             offset=offset,
#     230         )
#     231     except RuntimeError as error:
#     232         print(error)
#
# Cell In[6], line 94, in safe_api_call(method, description, **kwargs)
#      92 for attempt in range(1, MAX_RETRIES + 1):
#      93     try:
# ---> 94         response = method(**kwargs)
#      95         time.sleep(API_DELAY)
#      96         return response
#
# File ~\miniconda3\Lib\site-packages\vk_api\vk_api.py:1043, in VkApiMethod.__call__(self, **kwargs)
#    1040     if isinstance(v, (list, tuple)):
#    1041         kwargs[k] = ','.join(str(x) for x in v)
# -> 1043 return self._vk.method(self._method, kwargs)
#
# File ~\miniconda3\Lib\site-packages\vk_api\vk_api.py:895, in VkApi.method(self, method, values, captcha_sid, captcha_key, raw, with_cookies)
#     892 delay = self.RPS_DELAY - (time.time() - self.last_request)
#     894 if delay > 0:
# --> 895     time.sleep(delay)
#     897 response = self.http.post(
#     898     f'https://api.vk.com/method/{method}',
#     899     values,
#     900     headers=None if with_cookies else {'Cookie': ''},
#     901 )
#     902 self.last_request = time.time()
#
# KeyboardInterrupt:

# %%
# === Rebuild CSVs from cache (no API calls) ==================================
def _safe_json_load(path: Path):
    try:
        with path.open("r", encoding="utf-8") as fh:
            return json.load(fh)
    except json.JSONDecodeError:
        # Битый кэш — пропускаем
        return None

def _to_set(x):
    if x is None:
        return set()
    if isinstance(x, set):
        return x
    if isinstance(x, (list, tuple)):
        return {str(v).strip().lower() for v in x if v is not None and str(v).strip()}
    # fallback: одно значение -> множество из одного
    s = str(x).strip().lower()
    return {s} if s else set()

def rebuild_from_cache(
    target_ids: Optional[Iterable[int]] = None,
    out_dir: Path = OUTPUT_DIR
):
    """Собирает users.csv, friends.csv, groups.csv и features.csv только из кэша (без VK API)."""
    ensure_dir(out_dir)

    # 1) Загружаем профили
    profiles: Dict[int, dict] = {}
    if USERS_CACHE.exists():
        for p in USERS_CACHE.glob("*.json"):
            data = _safe_json_load(p)
            if not data or "id" not in data:
                continue
            try:
                uid = int(data["id"])
            except (TypeError, ValueError):
                continue

            # Приведение *_norm к set, т.к. в JSON они лежат списками/могут быть None
            data["universities_norm"] = _to_set(data.get("universities_norm"))
            data["faculties_norm"]    = _to_set(data.get("faculties_norm"))
            data["schools_norm"]      = _to_set(data.get("schools_norm"))
            data["works_norm"]        = _to_set(data.get("works_norm"))

            # Нормализуем city_norm на всякий случай
            data["city_norm"] = (
                str(data["city_norm"]).strip().lower()
                if data.get("city_norm") not in (None, "")
                else None
            )

            profiles[uid] = data

    if not profiles:
        print("⚠️ В кэше нет валидных профилей (data/cache/users/*.json).")
        return

    # 2) Загружаем друзей
    friends_map: Dict[int, Set[int]] = {}
    if FRIENDS_CACHE.exists():
        for p in FRIENDS_CACHE.glob("*.json"):
            data = _safe_json_load(p)
            if data is None:
                continue
            try:
                uid = int(p.stem)
            except ValueError:
                continue
            # в кэше друзья — список id; приводим к множеству int
            friends_map[uid] = {
                int(x) for x in data
                if isinstance(x, (int, str)) and str(x).isdigit()
            }
    # гарантируем ключи для всех известных профилей
    for uid in profiles.keys():
        friends_map.setdefault(uid, set())

    # 3) Загружаем группы
    groups_map: Dict[int, Set[int]] = {}
    if GROUPS_CACHE.exists():
        for p in GROUPS_CACHE.glob("*.json"):
            data = _safe_json_load(p)
            if data is None:
                continue
            try:
                uid = int(p.stem)
            except ValueError:
                continue
            groups_map[uid] = {
                int(x) for x in data
                if isinstance(x, (int, str)) and str(x).isdigit()
            }
    for uid in profiles.keys():
        groups_map.setdefault(uid, set())

    # 4) Экспортируем базовые CSV
    export_users(profiles, out_dir / "users.csv")
    export_friends(profiles, friends_map, out_dir / "friends.csv")
    export_groups(profiles, groups_map, out_dir / "groups.csv")
    print("✅ users.csv, friends.csv, groups.csv пересобраны из кэша.")

    # 5) Фичи по парам (локальная безопасная версия, без изменения глобальной compute_features)
    if target_ids is None:
        # по умолчанию — все собранные пользователи
        target_ids = list(profiles.keys())

    def _as_set(x):
        if isinstance(x, set): 
            return x
        if isinstance(x, (list, tuple)): 
            return set(x)
        return set()

    def _adamic_adar(common_friends: Set[int]) -> float:
        score = 0.0
        for fid in common_friends:
            deg = len(friends_map.get(fid, []))
            if deg <= 1:
                deg = profiles.get(fid, {}).get("friends_count")
            if deg and deg > 1:
                score += 1.0 / math.log(deg)
        return score

    feature_rows: List[dict] = []
    user_list = [uid for uid in target_ids if uid in profiles]
    user_list.sort()
    for i, uid_a in enumerate(user_list):
        for uid_b in user_list[i+1:]:
            pa = profiles[uid_a]; pb = profiles[uid_b]

            fa = friends_map.get(uid_a, set()) or set()
            fb = friends_map.get(uid_b, set()) or set()
            cf = fa & fb
            uf = fa | fb
            j_f = len(cf) / len(uf) if uf else 0.0

            ga = groups_map.get(uid_a, set()) or set()
            gb = groups_map.get(uid_b, set()) or set()
            cg = ga & gb
            ug = ga | gb
            j_g = len(cg) / len(ug) if ug else 0.0

            ca = pa.get("city_norm"); cb = pb.get("city_norm")
            same_city = int(ca is not None and cb is not None and ca == cb)

            same_university = int(bool(_as_set(pa.get("universities_norm")) &
                                       _as_set(pb.get("universities_norm"))))
            same_faculty    = int(bool(_as_set(pa.get("faculties_norm")) &
                                       _as_set(pb.get("faculties_norm"))))
            same_school     = int(bool(_as_set(pa.get("schools_norm")) &
                                       _as_set(pb.get("schools_norm"))))

            age_a = pa.get("age"); age_b = pb.get("age")
            age_diff = abs(age_a - age_b) if (age_a is not None and age_b is not None) else None

            feature_rows.append({
                "user_A": uid_a,
                "user_B": uid_b,
                "common_friends": len(cf),
                "jaccard_friends": j_f,
                "adamic_adar": _adamic_adar(cf),
                "same_city": same_city,
                "same_university": same_university,
                "same_faculty": same_faculty,
                "same_school": same_school,
                "age_diff": age_diff,
                "common_groups": len(cg),
                "jaccard_groups": j_g,
            })

    export_features(feature_rows, out_dir / "features.csv")
    print("✅ features.csv пересобран из кэша.")

# %%
rebuild_from_cache()
# Out:
# ✅ users.csv, friends.csv, groups.csv пересобраны из кэша.
# ✅ features.csv пересобран из кэша.
